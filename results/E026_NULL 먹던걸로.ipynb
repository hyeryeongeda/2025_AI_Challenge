# %% [markdown]
# # baseline v3
#
# 이 베이스라인 코드는 `사전학습 모델 로드`, `배치 학습`, `파인튜닝`, `양자화`, `PEFT` 등이 적용된 버전입니다.
#
# Colab의 GPU 환경에서 개발되었습니다.
# - 런타임 - 런타임 유형 변경 - GPU로 변경(T4 GPU 등)

# %% [markdown]
# # 환경 준비
#
# 개발 환경에 필요한 라이브러리 버전을 고정하고 최신 버전으로 라이브러리를 업데이트합니다.
#
# - 아래 셀 실행
# - 실행 완료 후 런타임 - 세션 다시 시작

# %%
# !pip -q install "transformers>=4.44.2" "accelerate>=0.34.2" "peft>=0.13.2" "bitsandbytes>=0.43.1" datasets pillow pandas torch torchvision --upgrade

# %% [markdown]
# # 데이터 준비
#
# 개발에 필요한 데이터를 준비합니다.
#
# - train.csv, train 폴더
# - test.csv, test 폴더
# - sample_submission.csv
#
# 본 베이스라인은 colab에서 구글 드라이브를 마운트하여 사용합니다.
#
# 데이터를 압축 해제하는데 몇 분 정도의 시간이 소요됩니다.
#
# #### 실습 참고 내용
#
#     챕터 2-2 합성 데이터 실습
#     - 구글 드라이브 마운트 : drive()

# %%
# 구글드라이브 마운트
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# 압축 해제
# !unzip "/content/drive/My Drive/data.zip" -d "/content/"
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
#   inflating: /content/test/test_2776.jpg
#   inflating: /content/test/test_2777.jpg
#   inflating: /content/test/test_2778.jpg
#   inflating: /content/test/test_2779.jpg
#   inflating: /content/test/test_2780.jpg
#   inflating: /content/test/test_2781.jpg
#   inflating: /content/test/test_2782.jpg
#   inflating: /content/test/test_2783.jpg
#   inflating: /content/test/test_2784.jpg
#   inflating: /content/test/test_2785.jpg
#   inflating: /content/test/test_2786.jpg
#   inflating: /content/test/test_2787.jpg
#   inflating: /content/test/test_2788.jpg
#   inflating: /content/test/test_2789.jpg
#   inflating: /content/test/test_2790.jpg
#   inflating: /content/test/test_2791.jpg
#   inflating: /content/test/test_2792.jpg
#   inflating: /content/test/test_2793.jpg
#   inflating: /content/test/test_2794.jpg
#   inflating: /content/test/test_2795.jpg
#   inflating: /content/test/test_2796.jpg
#   inflating: /content/test/test_2797.jpg
#   inflating: /content/test/test_2798.jpg
#   inflating: /content/test/test_2799.jpg
#   inflating: /content/test/test_2800.jpg
#   inflating: /content/test/test_2801.jpg
#   inflating: /content/test/test_2802.jpg
#   inflating: /content/test/test_2803.jpg
#   inflating: /content/test/test_2804.jpg
#   inflating: /content/test/test_2805.jpg
#   inflating: /content/test/test_2806.jpg
#   inflating: /content/test/test_2807.jpg
#   inflating: /content/test/test_2808.jpg
#   inflating: /content/test/test_2809.jpg
#   inflating: /content/test/test_2810.jpg
#   inflating: /content/test/test_2811.jpg
#   inflating: /content/test/test_2812.jpg
#   inflating: /content/test/test_2813.jpg
#   inflating: /content/test/test_2814.jpg
#   inflating: /content/test/test_2815.jpg
#   inflating: /content/test/test_2816.jpg
#   inflating: /content/test/test_2817.jpg
#   inflating: /content/test/test_2818.jpg
#   inflating: /content/test/test_2819.jpg
#   inflating: /content/test/test_2820.jpg
#   inflating: /content/test/test_2821.jpg
#   inflating: /content/test/test_2822.jpg
#   inflating: /content/test/test_2823.jpg
#   inflating: /content/test/test_2824.jpg
#   inflating: /content/test/test_2825.jpg
#   inflating: /content/test/test_2826.jpg
#   inflating: /content/test/test_2827.jpg
#   inflating: /content/test/test_2828.jpg
#   inflating: /content/test/test_2829.jpg
#   inflating: /content/test/test_2830.jpg
#   inflating: /content/test/test_2831.jpg
#   inflating: /content/test/test_2832.jpg
#   inflating: /content/test/test_2833.jpg
#   inflating: /content/test/test_2834.jpg
#   inflating: /content/test/test_2835.jpg
#   inflating: /content/test/test_2836.jpg
#   inflating: /content/test/test_2837.jpg
#   inflating: /content/test/test_2838.jpg
#   inflating: /content/test/test_2839.jpg
#   inflating: /content/test/test_2840.jpg
#   inflating: /content/test/test_2841.jpg
#   inflating: /content/test/test_2842.jpg
#   inflating: /content/test/test_2843.jpg
#   inflating: /content/test/test_2844.jpg
#   inflating: /content/test/test_2845.jpg
#   inflating: /content/test/test_2846.jpg
#   inflating: /content/test/test_2847.jpg
#   inflating: /content/test/test_2848.jpg
#   inflating: /content/test/test_2849.jpg
#   inflating: /content/test/test_2850.jpg
#   inflating: /content/test/test_2851.jpg
#   inflating: /content/test/test_2852.jpg
#   inflating: /content/test/test_2853.jpg
#   inflating: /content/test/test_2854.jpg
#   inflating: /content/test/test_2855.jpg
#   inflating: /content/test/test_2856.jpg
#   inflating: /content/test/test_2857.jpg
#   inflating: /content/test/test_2858.jpg
#   inflating: /content/test/test_2859.jpg
#   inflating: /content/test/test_2860.jpg
#   inflating: /content/test/test_2861.jpg
#   inflating: /content/test/test_2862.jpg
#   inflating: /content/test/test_2863.jpg
#   inflating: /content/test/test_2864.jpg
#   inflating: /content/test/test_2865.jpg
#   inflating: /content/test/test_2866.jpg
#   inflating: /content/test/test_2867.jpg
#   inflating: /content/test/test_2868.jpg
#   inflating: /content/test/test_2869.jpg
#   inflating: /content/test/test_2870.jpg
#   inflating: /content/test/test_2871.jpg
#   inflating: /content/test/test_2872.jpg
#   inflating: /content/test/test_2873.jpg
#   inflating: /content/test/test_2874.jpg
#   inflating: /content/test/test_2875.jpg
#   inflating: /content/test/test_2876.jpg
#   inflating: /content/test/test_2877.jpg
#   inflating: /content/test/test_2878.jpg
#   inflating: /content/test/test_2879.jpg
#   inflating: /content/test/test_2880.jpg
#   inflating: /content/test/test_2881.jpg
#   inflating: /content/test/test_2882.jpg
#   inflating: /content/test/test_2883.jpg
#   inflating: /content/test/test_2884.jpg
#   inflating: /content/test/test_2885.jpg
#   inflating: /content/test/test_2886.jpg
#   inflating: /content/test/test_2887.jpg
#   inflating: /content/test/test_2888.jpg
#   inflating: /content/test/test_2889.jpg
#   inflating: /content/test/test_2890.jpg
#   inflating: /content/test/test_2891.jpg
#   inflating: /content/test/test_2892.jpg
#   inflating: /content/test/test_2893.jpg
#   inflating: /content/test/test_2894.jpg
#   inflating: /content/test/test_2895.jpg
#   inflating: /content/test/test_2896.jpg
#   inflating: /content/test/test_2897.jpg
#   inflating: /content/test/test_2898.jpg
#   inflating: /content/test/test_2899.jpg
#   inflating: /content/test/test_2900.jpg
#   inflating: /content/test/test_2901.jpg
#   inflating: /content/test/test_2902.jpg
#   inflating: /content/test/test_2903.jpg
#   inflating: /content/test/test_2904.jpg
#   inflating: /content/test/test_2905.jpg
#   inflating: /content/test/test_2906.jpg
#   inflating: /content/test/test_2907.jpg
#   inflating: /content/test/test_2908.jpg
#   inflating: /content/test/test_2909.jpg
#   inflating: /content/test/test_2910.jpg
#   inflating: /content/test/test_2911.jpg
#   inflating: /content/test/test_2912.jpg
#   inflating: /content/test/test_2913.jpg
#   inflating: /content/test/test_2914.jpg
#   inflating: /content/test/test_2915.jpg
#   inflating: /content/test/test_2916.jpg
#   inflating: /content/test/test_2917.jpg
#   inflating: /content/test/test_2918.jpg
#   inflating: /content/test/test_2919.jpg
#   inflating: /content/test/test_2920.jpg
#   inflating: /content/test/test_2921.jpg
#   inflating: /content/test/test_2922.jpg
#   inflating: /content/test/test_2923.jpg
#   inflating: /content/test/test_2924.jpg
#   inflating: /content/test/test_2925.jpg
#   inflating: /content/test/test_2926.jpg
#   inflating: /content/test/test_2927.jpg
#   inflating: /content/test/test_2928.jpg
#   inflating: /content/test/test_2929.jpg
#   inflating: /content/test/test_2930.jpg
#   inflating: /content/test/test_2931.jpg
#   inflating: /content/test/test_2932.jpg
#   inflating: /content/test/test_2933.jpg
#   inflating: /content/test/test_2934.jpg
#   inflating: /content/test/test_2935.jpg
#   inflating: /content/test/test_2936.jpg
#   inflating: /content/test/test_2937.jpg
#   inflating: /content/test/test_2938.jpg
#   inflating: /content/test/test_2939.jpg
#   inflating: /content/test/test_2940.jpg
#   inflating: /content/test/test_2941.jpg
#   inflating: /content/test/test_2942.jpg
#   inflating: /content/test/test_2943.jpg
#   inflating: /content/test/test_2944.jpg
#   inflating: /content/test/test_2945.jpg
#   inflating: /content/test/test_2946.jpg
#   inflating: /content/test/test_2947.jpg
#   inflating: /content/test/test_2948.jpg
#   inflating: /content/test/test_2949.jpg
#   inflating: /content/test/test_2950.jpg
#   inflating: /content/test/test_2951.jpg
#   inflating: /content/test/test_2952.jpg
#   inflating: /content/test/test_2953.jpg
#   inflating: /content/test/test_2954.jpg
#   inflating: /content/test/test_2955.jpg
#   inflating: /content/test/test_2956.jpg
#   inflating: /content/test/test_2957.jpg
#   inflating: /content/test/test_2958.jpg
#   inflating: /content/test/test_2959.jpg
#   inflating: /content/test/test_2960.jpg
#   inflating: /content/test/test_2961.jpg
#   inflating: /content/test/test_2962.jpg
#   inflating: /content/test/test_2963.jpg
#   inflating: /content/test/test_2964.jpg
#   inflating: /content/test/test_2965.jpg
#   inflating: /content/test/test_2966.jpg
#   inflating: /content/test/test_2967.jpg
#   inflating: /content/test/test_2968.jpg
#   inflating: /content/test/test_2969.jpg
#   inflating: /content/test/test_2970.jpg
#   inflating: /content/test/test_2971.jpg
#   inflating: /content/test/test_2972.jpg
#   inflating: /content/test/test_2973.jpg
#   inflating: /content/test/test_2974.jpg
#   inflating: /content/test/test_2975.jpg
#   inflating: /content/test/test_2976.jpg
#   inflating: /content/test/test_2977.jpg
#   inflating: /content/test/test_2978.jpg
#   inflating: /content/test/test_2979.jpg
#   inflating: /content/test/test_2980.jpg
#   inflating: /content/test/test_2981.jpg
#   inflating: /content/test/test_2982.jpg
#   inflating: /content/test/test_2983.jpg
#   inflating: /content/test/test_2984.jpg
#   inflating: /content/test/test_2985.jpg
#   inflating: /content/test/test_2986.jpg
#   inflating: /content/test/test_2987.jpg
#   inflating: /content/test/test_2988.jpg
#   inflating: /content/test/test_2989.jpg
#   inflating: /content/test/test_2990.jpg
#   inflating: /content/test/test_2991.jpg
#   inflating: /content/test/test_2992.jpg
#   inflating: /content/test/test_2993.jpg
#   inflating: /content/test/test_2994.jpg
#   inflating: /content/test/test_2995.jpg
#   inflating: /content/test/test_2996.jpg
#   inflating: /content/test/test_2997.jpg
#   inflating: /content/test/test_2998.jpg
#   inflating: /content/test/test_2999.jpg
#   inflating: /content/test/test_3000.jpg
#   inflating: /content/test/test_3001.jpg
#   inflating: /content/test/test_3002.jpg
#   inflating: /content/test/test_3003.jpg
#   inflating: /content/test/test_3004.jpg
#   inflating: /content/test/test_3005.jpg
#   inflating: /content/test/test_3006.jpg
#   inflating: /content/test/test_3007.jpg
#   inflating: /content/test/test_3008.jpg
#   inflating: /content/test/test_3009.jpg
#   inflating: /content/test/test_3010.jpg
#   inflating: /content/test/test_3011.jpg
#   inflating: /content/test/test_3012.jpg
#   inflating: /content/test/test_3013.jpg
#   inflating: /content/test/test_3014.jpg
#   inflating: /content/test/test_3015.jpg
#   inflating: /content/test/test_3016.jpg
#   inflating: /content/test/test_3017.jpg
#   inflating: /content/test/test_3018.jpg
#   inflating: /content/test/test_3019.jpg
#   inflating: /content/test/test_3020.jpg
#   inflating: /content/test/test_3021.jpg
#   inflating: /content/test/test_3022.jpg
#   inflating: /content/test/test_3023.jpg
#   inflating: /content/test/test_3024.jpg
#   inflating: /content/test/test_3025.jpg
#   inflating: /content/test/test_3026.jpg
#   inflating: /content/test/test_3027.jpg
#   inflating: /content/test/test_3028.jpg
#   inflating: /content/test/test_3029.jpg
#   inflating: /content/test/test_3030.jpg
#   inflating: /content/test/test_3031.jpg
#   inflating: /content/test/test_3032.jpg
#   inflating: /content/test/test_3033.jpg
#   inflating: /content/test/test_3034.jpg
#   inflating: /content/test/test_3035.jpg
#   inflating: /content/test/test_3036.jpg
#   inflating: /content/test/test_3037.jpg
#   inflating: /content/test/test_3038.jpg
#   inflating: /content/test/test_3039.jpg
#   inflating: /content/test/test_3040.jpg
#   inflating: /content/test/test_3041.jpg
#   inflating: /content/test/test_3042.jpg
#   inflating: /content/test/test_3043.jpg
#   inflating: /content/test/test_3044.jpg
#   inflating: /content/test/test_3045.jpg
#   inflating: /content/test/test_3046.jpg
#   inflating: /content/test/test_3047.jpg
#   inflating: /content/test/test_3048.jpg
#   inflating: /content/test/test_3049.jpg
#   inflating: /content/test/test_3050.jpg
#   inflating: /content/test/test_3051.jpg
#   inflating: /content/test/test_3052.jpg
#   inflating: /content/test/test_3053.jpg
#   inflating: /content/test/test_3054.jpg
#   inflating: /content/test/test_3055.jpg
#   inflating: /content/test/test_3056.jpg
#   inflating: /content/test/test_3057.jpg
#   inflating: /content/test/test_3058.jpg
#   inflating: /content/test/test_3059.jpg
#   inflating: /content/test/test_3060.jpg
#   inflating: /content/test/test_3061.jpg
#   inflating: /content/test/test_3062.jpg
#   inflating: /content/test/test_3063.jpg
#   inflating: /content/test/test_3064.jpg
#   inflating: /content/test/test_3065.jpg
#   inflating: /content/test/test_3066.jpg
#   inflating: /content/test/test_3067.jpg
#   inflating: /content/test/test_3068.jpg
#   inflating: /content/test/test_3069.jpg
#   inflating: /content/test/test_3070.jpg
#   inflating: /content/test/test_3071.jpg
#   inflating: /content/test/test_3072.jpg
#   inflating: /content/test/test_3073.jpg
#   inflating: /content/test/test_3074.jpg
#   inflating: /content/test/test_3075.jpg
#   inflating: /content/test/test_3076.jpg
#   inflating: /content/test/test_3077.jpg
#   inflating: /content/test/test_3078.jpg
#   inflating: /content/test/test_3079.jpg
#   inflating: /content/test/test_3080.jpg
#   inflating: /content/test/test_3081.jpg
#   inflating: /content/test/test_3082.jpg
#   inflating: /content/test/test_3083.jpg
#   inflating: /content/test/test_3084.jpg
#   inflating: /content/test/test_3085.jpg
#   inflating: /content/test/test_3086.jpg
#   inflating: /content/test/test_3087.jpg
#   inflating: /content/test/test_3088.jpg
#   inflating: /content/test/test_3089.jpg
#   inflating: /content/test/test_3090.jpg
#   inflating: /content/test/test_3091.jpg
#   inflating: /content/test/test_3092.jpg
#   inflating: /content/test/test_3093.jpg
#   inflating: /content/test/test_3094.jpg
#   inflating: /content/test/test_3095.jpg
#   inflating: /content/test/test_3096.jpg
#   inflating: /content/test/test_3097.jpg
#   inflating: /content/test/test_3098.jpg
#   inflating: /content/test/test_3099.jpg
#   inflating: /content/test/test_3100.jpg
#   inflating: /content/test/test_3101.jpg
#   inflating: /content/test/test_3102.jpg
#   inflating: /content/test/test_3103.jpg
#   inflating: /content/test/test_3104.jpg
#   inflating: /content/test/test_3105.jpg
#   inflating: /content/test/test_3106.jpg
#   inflating: /content/test/test_3107.jpg
#   inflating: /content/test/test_3108.jpg
#   inflating: /content/test/test_3109.jpg
#   inflating: /content/test/test_3110.jpg
#   inflating: /content/test/test_3111.jpg
#   inflating: /content/test/test_3112.jpg
#   inflating: /content/test/test_3113.jpg
#   inflating: /content/test/test_3114.jpg
#   inflating: /content/test/test_3115.jpg
#   inflating: /content/test/test_3116.jpg
#   inflating: /content/test/test_3117.jpg
#   inflating: /content/test/test_3118.jpg
#   inflating: /content/test/test_3119.jpg
#   inflating: /content/test/test_3120.jpg
#   inflating: /content/test/test_3121.jpg
#   inflating: /content/test/test_3122.jpg
#   inflating: /content/test/test_3123.jpg
#   inflating: /content/test/test_3124.jpg
#   inflating: /content/test/test_3125.jpg
#   inflating: /content/test/test_3126.jpg
#   inflating: /content/test/test_3127.jpg
#   inflating: /content/test/test_3128.jpg
#   inflating: /content/test/test_3129.jpg
#   inflating: /content/test/test_3130.jpg
#   inflating: /content/test/test_3131.jpg
#   inflating: /content/test/test_3132.jpg
#   inflating: /content/test/test_3133.jpg
#   inflating: /content/test/test_3134.jpg
#   inflating: /content/test/test_3135.jpg
#   inflating: /content/test/test_3136.jpg
#   inflating: /content/test/test_3137.jpg
#   inflating: /content/test/test_3138.jpg
#   inflating: /content/test/test_3139.jpg
#   inflating: /content/test/test_3140.jpg
#   inflating: /content/test/test_3141.jpg
#   inflating: /content/test/test_3142.jpg
#   inflating: /content/test/test_3143.jpg
#   inflating: /content/test/test_3144.jpg
#   inflating: /content/test/test_3145.jpg
#   inflating: /content/test/test_3146.jpg
#   inflating: /content/test/test_3147.jpg
#   inflating: /content/test/test_3148.jpg
#   inflating: /content/test/test_3149.jpg
#   inflating: /content/test/test_3150.jpg
#   inflating: /content/test/test_3151.jpg
#   inflating: /content/test/test_3152.jpg
#   inflating: /content/test/test_3153.jpg
#   inflating: /content/test/test_3154.jpg
#   inflating: /content/test/test_3155.jpg
#   inflating: /content/test/test_3156.jpg
#   inflating: /content/test/test_3157.jpg
#   inflating: /content/test/test_3158.jpg
#   inflating: /content/test/test_3159.jpg
#   inflating: /content/test/test_3160.jpg
#   inflating: /content/test/test_3161.jpg
#   inflating: /content/test/test_3162.jpg
#   inflating: /content/test/test_3163.jpg
#   inflating: /content/test/test_3164.jpg
#   inflating: /content/test/test_3165.jpg
#   inflating: /content/test/test_3166.jpg
#   inflating: /content/test/test_3167.jpg
#   inflating: /content/test/test_3168.jpg
#   inflating: /content/test/test_3169.jpg
#   inflating: /content/test/test_3170.jpg
#   inflating: /content/test/test_3171.jpg
#   inflating: /content/test/test_3172.jpg
#   inflating: /content/test/test_3173.jpg
#   inflating: /content/test/test_3174.jpg
#   inflating: /content/test/test_3175.jpg
#   inflating: /content/test/test_3176.jpg
#   inflating: /content/test/test_3177.jpg
#   inflating: /content/test/test_3178.jpg
#   inflating: /content/test/test_3179.jpg
#   inflating: /content/test/test_3180.jpg
#   inflating: /content/test/test_3181.jpg
#   inflating: /content/test/test_3182.jpg
#   inflating: /content/test/test_3183.jpg
#   inflating: /content/test/test_3184.jpg
#   inflating: /content/test/test_3185.jpg
#   inflating: /content/test/test_3186.jpg
#   inflating: /content/test/test_3187.jpg
#   inflating: /content/test/test_3188.jpg
#   inflating: /content/test/test_3189.jpg
#   inflating: /content/test/test_3190.jpg
#   inflating: /content/test/test_3191.jpg
#   inflating: /content/test/test_3192.jpg
#   inflating: /content/test/test_3193.jpg
#   inflating: /content/test/test_3194.jpg
#   inflating: /content/test/test_3195.jpg
#   inflating: /content/test/test_3196.jpg
#   inflating: /content/test/test_3197.jpg
#   inflating: /content/test/test_3198.jpg
#   inflating: /content/test/test_3199.jpg
#   inflating: /content/test/test_3200.jpg
#   inflating: /content/test/test_3201.jpg
#   inflating: /content/test/test_3202.jpg
#   inflating: /content/test/test_3203.jpg
#   inflating: /content/test/test_3204.jpg
#   inflating: /content/test/test_3205.jpg
#   inflating: /content/test/test_3206.jpg
#   inflating: /content/test/test_3207.jpg
#   inflating: /content/test/test_3208.jpg
#   inflating: /content/test/test_3209.jpg
#   inflating: /content/test/test_3210.jpg
#   inflating: /content/test/test_3211.jpg
#   inflating: /content/test/test_3212.jpg
#   inflating: /content/test/test_3213.jpg
#   inflating: /content/test/test_3214.jpg
#   inflating: /content/test/test_3215.jpg
#   inflating: /content/test/test_3216.jpg
#   inflating: /content/test/test_3217.jpg
#   inflating: /content/test/test_3218.jpg
#   inflating: /content/test/test_3219.jpg
#   inflating: /content/test/test_3220.jpg
#   inflating: /content/test/test_3221.jpg
#   inflating: /content/test/test_3222.jpg
#   inflating: /content/test/test_3223.jpg
#   inflating: /content/test/test_3224.jpg
#   inflating: /content/test/test_3225.jpg
#   inflating: /content/test/test_3226.jpg
#   inflating: /content/test/test_3227.jpg
#   inflating: /content/test/test_3228.jpg
#   inflating: /content/test/test_3229.jpg
#   inflating: /content/test/test_3230.jpg
#   inflating: /content/test/test_3231.jpg
#   inflating: /content/test/test_3232.jpg
#   inflating: /content/test/test_3233.jpg
#   inflating: /content/test/test_3234.jpg
#   inflating: /content/test/test_3235.jpg
#   inflating: /content/test/test_3236.jpg
#   inflating: /content/test/test_3237.jpg
#   inflating: /content/test/test_3238.jpg
#   inflating: /content/test/test_3239.jpg
#   inflating: /content/test/test_3240.jpg
#   inflating: /content/test/test_3241.jpg
#   inflating: /content/test/test_3242.jpg
#   inflating: /content/test/test_3243.jpg
#   inflating: /content/test/test_3244.jpg
#   inflating: /content/test/test_3245.jpg
#   inflating: /content/test/test_3246.jpg
#   inflating: /content/test/test_3247.jpg
#   inflating: /content/test/test_3248.jpg
#   inflating: /content/test/test_3249.jpg
#   inflating: /content/test/test_3250.jpg
#   inflating: /content/test/test_3251.jpg
#   inflating: /content/test/test_3252.jpg
#   inflating: /content/test/test_3253.jpg
#   inflating: /content/test/test_3254.jpg
#   inflating: /content/test/test_3255.jpg
#   inflating: /content/test/test_3256.jpg
#   inflating: /content/test/test_3257.jpg
#   inflating: /content/test/test_3258.jpg
#   inflating: /content/test/test_3259.jpg
#   inflating: /content/test/test_3260.jpg
#   inflating: /content/test/test_3261.jpg
#   inflating: /content/test/test_3262.jpg
#   inflating: /content/test/test_3263.jpg
#   inflating: /content/test/test_3264.jpg
#   inflating: /content/test/test_3265.jpg
#   inflating: /content/test/test_3266.jpg
#   inflating: /content/test/test_3267.jpg
#   inflating: /content/test/test_3268.jpg
#   inflating: /content/test/test_3269.jpg
#   inflating: /content/test/test_3270.jpg
#   inflating: /content/test/test_3271.jpg
#   inflating: /content/test/test_3272.jpg
#   inflating: /content/test/test_3273.jpg
#   inflating: /content/test/test_3274.jpg
#   inflating: /content/test/test_3275.jpg
#   inflating: /content/test/test_3276.jpg
#   inflating: /content/test/test_3277.jpg
#   inflating: /content/test/test_3278.jpg
#   inflating: /content/test/test_3279.jpg
#   inflating: /content/test/test_3280.jpg
#   inflating: /content/test/test_3281.jpg
#   inflating: /content/test/test_3282.jpg
#   inflating: /content/test/test_3283.jpg
#   inflating: /content/test/test_3284.jpg
#   inflating: /content/test/test_3285.jpg
#   inflating: /content/test/test_3286.jpg
#   inflating: /content/test/test_3287.jpg
#   inflating: /content/test/test_3288.jpg
#   inflating: /content/test/test_3289.jpg
#   inflating: /content/test/test_3290.jpg
#   inflating: /content/test/test_3291.jpg
#   inflating: /content/test/test_3292.jpg
#   inflating: /content/test/test_3293.jpg
#   inflating: /content/test/test_3294.jpg
#   inflating: /content/test/test_3295.jpg
#   inflating: /content/test/test_3296.jpg
#   inflating: /content/test/test_3297.jpg
#   inflating: /content/test/test_3298.jpg
#   inflating: /content/test/test_3299.jpg
#   inflating: /content/test/test_3300.jpg
#   inflating: /content/test/test_3301.jpg
#   inflating: /content/test/test_3302.jpg
#   inflating: /content/test/test_3303.jpg
#   inflating: /content/test/test_3304.jpg
#   inflating: /content/test/test_3305.jpg
#   inflating: /content/test/test_3306.jpg
#   inflating: /content/test/test_3307.jpg
#   inflating: /content/test/test_3308.jpg
#   inflating: /content/test/test_3309.jpg
#   inflating: /content/test/test_3310.jpg
#   inflating: /content/test/test_3311.jpg
#   inflating: /content/test/test_3312.jpg
#   inflating: /content/test/test_3313.jpg
#   inflating: /content/test/test_3314.jpg
#   inflating: /content/test/test_3315.jpg
#   inflating: /content/test/test_3316.jpg
#   inflating: /content/test/test_3317.jpg
#   inflating: /content/test/test_3318.jpg
#   inflating: /content/test/test_3319.jpg
#   inflating: /content/test/test_3320.jpg
#   inflating: /content/test/test_3321.jpg
#   inflating: /content/test/test_3322.jpg
#   inflating: /content/test/test_3323.jpg
#   inflating: /content/test/test_3324.jpg
#   inflating: /content/test/test_3325.jpg
#   inflating: /content/test/test_3326.jpg
#   inflating: /content/test/test_3327.jpg
#   inflating: /content/test/test_3328.jpg
#   inflating: /content/test/test_3329.jpg
#   inflating: /content/test/test_3330.jpg
#   inflating: /content/test/test_3331.jpg
#   inflating: /content/test/test_3332.jpg
#   inflating: /content/test/test_3333.jpg
#   inflating: /content/test/test_3334.jpg
#   inflating: /content/test/test_3335.jpg
#   inflating: /content/test/test_3336.jpg
#   inflating: /content/test/test_3337.jpg
#   inflating: /content/test/test_3338.jpg
#   inflating: /content/test/test_3339.jpg
#   inflating: /content/test/test_3340.jpg
#   inflating: /content/test/test_3341.jpg
#   inflating: /content/test/test_3342.jpg
#   inflating: /content/test/test_3343.jpg
#   inflating: /content/test/test_3344.jpg
#   inflating: /content/test/test_3345.jpg
#   inflating: /content/test/test_3346.jpg
#   inflating: /content/test/test_3347.jpg
#   inflating: /content/test/test_3348.jpg
#   inflating: /content/test/test_3349.jpg
#   inflating: /content/test/test_3350.jpg
#   inflating: /content/test/test_3351.jpg
#   inflating: /content/test/test_3352.jpg
#   inflating: /content/test/test_3353.jpg
#   inflating: /content/test/test_3354.jpg
#   inflating: /content/test/test_3355.jpg
#   inflating: /content/test/test_3356.jpg
#   inflating: /content/test/test_3357.jpg
#   inflating: /content/test/test_3358.jpg
#   inflating: /content/test/test_3359.jpg
#   inflating: /content/test/test_3360.jpg
#   inflating: /content/test/test_3361.jpg
#   inflating: /content/test/test_3362.jpg
#   inflating: /content/test/test_3363.jpg
#   inflating: /content/test/test_3364.jpg
#   inflating: /content/test/test_3365.jpg
#   inflating: /content/test/test_3366.jpg
#   inflating: /content/test/test_3367.jpg
#   inflating: /content/test/test_3368.jpg
#   inflating: /content/test/test_3369.jpg
#   inflating: /content/test/test_3370.jpg
#   inflating: /content/test/test_3371.jpg
#   inflating: /content/test/test_3372.jpg
#   inflating: /content/test/test_3373.jpg
#   inflating: /content/test/test_3374.jpg
#   inflating: /content/test/test_3375.jpg
#   inflating: /content/test/test_3376.jpg
#   inflating: /content/test/test_3377.jpg
#   inflating: /content/test/test_3378.jpg
#   inflating: /content/test/test_3379.jpg
#   inflating: /content/test/test_3380.jpg
#   inflating: /content/test/test_3381.jpg
#   inflating: /content/test/test_3382.jpg
#   inflating: /content/test/test_3383.jpg
#   inflating: /content/test/test_3384.jpg
#   inflating: /content/test/test_3385.jpg
#   inflating: /content/test/test_3386.jpg
#   inflating: /content/test/test_3387.jpg
#   inflating: /content/test/test_3388.jpg
#   inflating: /content/test/test_3389.jpg
#   inflating: /content/test/test_3390.jpg
#   inflating: /content/test/test_3391.jpg
#   inflating: /content/test/test_3392.jpg
#   inflating: /content/test/test_3393.jpg
#   inflating: /content/test/test_3394.jpg
#   inflating: /content/test/test_3395.jpg
#   inflating: /content/test/test_3396.jpg
#   inflating: /content/test/test_3397.jpg
#   inflating: /content/test/test_3398.jpg
#   inflating: /content/test/test_3399.jpg
#   inflating: /content/test/test_3400.jpg
#   inflating: /content/test/test_3401.jpg
#   inflating: /content/test/test_3402.jpg
#   inflating: /content/test/test_3403.jpg
#   inflating: /content/test/test_3404.jpg
#   inflating: /content/test/test_3405.jpg
#   inflating: /content/test/test_3406.jpg
#   inflating: /content/test/test_3407.jpg
#   inflating: /content/test/test_3408.jpg
#   inflating: /content/test/test_3409.jpg
#   inflating: /content/test/test_3410.jpg
#   inflating: /content/test/test_3411.jpg
#   inflating: /content/test/test_3412.jpg
#   inflating: /content/test/test_3413.jpg
#   inflating: /content/test/test_3414.jpg
#   inflating: /content/test/test_3415.jpg
#   inflating: /content/test/test_3416.jpg
#   inflating: /content/test/test_3417.jpg
#   inflating: /content/test/test_3418.jpg
#   inflating: /content/test/test_3419.jpg
#   inflating: /content/test/test_3420.jpg
#   inflating: /content/test/test_3421.jpg
#   inflating: /content/test/test_3422.jpg
#   inflating: /content/test/test_3423.jpg
#   inflating: /content/test/test_3424.jpg
#   inflating: /content/test/test_3425.jpg
#   inflating: /content/test/test_3426.jpg
#   inflating: /content/test/test_3427.jpg
#   inflating: /content/test/test_3428.jpg
#   inflating: /content/test/test_3429.jpg
#   inflating: /content/test/test_3430.jpg
#   inflating: /content/test/test_3431.jpg
#   inflating: /content/test/test_3432.jpg
#   inflating: /content/test/test_3433.jpg
#   inflating: /content/test/test_3434.jpg
#   inflating: /content/test/test_3435.jpg
#   inflating: /content/test/test_3436.jpg
#   inflating: /content/test/test_3437.jpg
#   inflating: /content/test/test_3438.jpg
#   inflating: /content/test/test_3439.jpg
#   inflating: /content/test/test_3440.jpg
#   inflating: /content/test/test_3441.jpg
#   inflating: /content/test/test_3442.jpg
#   inflating: /content/test/test_3443.jpg
#   inflating: /content/test/test_3444.jpg
#   inflating: /content/test/test_3445.jpg
#   inflating: /content/test/test_3446.jpg
#   inflating: /content/test/test_3447.jpg
#   inflating: /content/test/test_3448.jpg
#   inflating: /content/test/test_3449.jpg
#   inflating: /content/test/test_3450.jpg
#   inflating: /content/test/test_3451.jpg
#   inflating: /content/test/test_3452.jpg
#   inflating: /content/test/test_3453.jpg
#   inflating: /content/test/test_3454.jpg
#   inflating: /content/test/test_3455.jpg
#   inflating: /content/test/test_3456.jpg
#   inflating: /content/test/test_3457.jpg
#   inflating: /content/test/test_3458.jpg
#   inflating: /content/test/test_3459.jpg
#   inflating: /content/test/test_3460.jpg
#   inflating: /content/test/test_3461.jpg
#   inflating: /content/test/test_3462.jpg
#   inflating: /content/test/test_3463.jpg
#   inflating: /content/test/test_3464.jpg
#   inflating: /content/test/test_3465.jpg
#   inflating: /content/test/test_3466.jpg
#   inflating: /content/test/test_3467.jpg
#   inflating: /content/test/test_3468.jpg
#   inflating: /content/test/test_3469.jpg
#   inflating: /content/test/test_3470.jpg
#   inflating: /content/test/test_3471.jpg
#   inflating: /content/test/test_3472.jpg
#   inflating: /content/test/test_3473.jpg
#   inflating: /content/test/test_3474.jpg
#   inflating: /content/test/test_3475.jpg
#   inflating: /content/test/test_3476.jpg
#   inflating: /content/test/test_3477.jpg
#   inflating: /content/test/test_3478.jpg
#   inflating: /content/test/test_3479.jpg
#   inflating: /content/test/test_3480.jpg
#   inflating: /content/test/test_3481.jpg
#   inflating: /content/test/test_3482.jpg
#   inflating: /content/test/test_3483.jpg
#   inflating: /content/test/test_3484.jpg
#   inflating: /content/test/test_3485.jpg
#   inflating: /content/test/test_3486.jpg
#   inflating: /content/test/test_3487.jpg
#   inflating: /content/test/test_3488.jpg
#   inflating: /content/test/test_3489.jpg
#   inflating: /content/test/test_3490.jpg
#   inflating: /content/test/test_3491.jpg
#   inflating: /content/test/test_3492.jpg
#   inflating: /content/test/test_3493.jpg
#   inflating: /content/test/test_3494.jpg
#   inflating: /content/test/test_3495.jpg
#   inflating: /content/test/test_3496.jpg
#   inflating: /content/test/test_3497.jpg
#   inflating: /content/test/test_3498.jpg
#   inflating: /content/test/test_3499.jpg
#   inflating: /content/test/test_3500.jpg
#   inflating: /content/test/test_3501.jpg
#   inflating: /content/test/test_3502.jpg
#   inflating: /content/test/test_3503.jpg
#   inflating: /content/test/test_3504.jpg
#   inflating: /content/test/test_3505.jpg
#   inflating: /content/test/test_3506.jpg
#   inflating: /content/test/test_3507.jpg
#   inflating: /content/test/test_3508.jpg
#   inflating: /content/test/test_3509.jpg
#   inflating: /content/test/test_3510.jpg
#   inflating: /content/test/test_3511.jpg
#   inflating: /content/test/test_3512.jpg
#   inflating: /content/test/test_3513.jpg
#   inflating: /content/test/test_3514.jpg
#   inflating: /content/test/test_3515.jpg
#   inflating: /content/test/test_3516.jpg
#   inflating: /content/test/test_3517.jpg
#   inflating: /content/test/test_3518.jpg
#   inflating: /content/test/test_3519.jpg
#   inflating: /content/test/test_3520.jpg
#   inflating: /content/test/test_3521.jpg
#   inflating: /content/test/test_3522.jpg
#   inflating: /content/test/test_3523.jpg
#   inflating: /content/test/test_3524.jpg
#   inflating: /content/test/test_3525.jpg
#   inflating: /content/test/test_3526.jpg
#   inflating: /content/test/test_3527.jpg
#   inflating: /content/test/test_3528.jpg
#   inflating: /content/test/test_3529.jpg
#   inflating: /content/test/test_3530.jpg
#   inflating: /content/test/test_3531.jpg
#   inflating: /content/test/test_3532.jpg
#   inflating: /content/test/test_3533.jpg
#   inflating: /content/test/test_3534.jpg
#   inflating: /content/test/test_3535.jpg
#   inflating: /content/test/test_3536.jpg
#   inflating: /content/test/test_3537.jpg
#   inflating: /content/test/test_3538.jpg
#   inflating: /content/test/test_3539.jpg
#   inflating: /content/test/test_3540.jpg
#   inflating: /content/test/test_3541.jpg
#   inflating: /content/test/test_3542.jpg
#   inflating: /content/test/test_3543.jpg
#   inflating: /content/test/test_3544.jpg
#   inflating: /content/test/test_3545.jpg
#   inflating: /content/test/test_3546.jpg
#   inflating: /content/test/test_3547.jpg
#   inflating: /content/test/test_3548.jpg
#   inflating: /content/test/test_3549.jpg
#   inflating: /content/test/test_3550.jpg
#   inflating: /content/test/test_3551.jpg
#   inflating: /content/test/test_3552.jpg
#   inflating: /content/test/test_3553.jpg
#   inflating: /content/test/test_3554.jpg
#   inflating: /content/test/test_3555.jpg
#   inflating: /content/test/test_3556.jpg
#   inflating: /content/test/test_3557.jpg
#   inflating: /content/test/test_3558.jpg
#   inflating: /content/test/test_3559.jpg
#   inflating: /content/test/test_3560.jpg
#   inflating: /content/test/test_3561.jpg
#   inflating: /content/test/test_3562.jpg
#   inflating: /content/test/test_3563.jpg
#   inflating: /content/test/test_3564.jpg
#   inflating: /content/test/test_3565.jpg
#   inflating: /content/test/test_3566.jpg
#   inflating: /content/test/test_3567.jpg
#   inflating: /content/test/test_3568.jpg
#   inflating: /content/test/test_3569.jpg
#   inflating: /content/test/test_3570.jpg
#   inflating: /content/test/test_3571.jpg
#   inflating: /content/test/test_3572.jpg
#   inflating: /content/test/test_3573.jpg
#   inflating: /content/test/test_3574.jpg
#   inflating: /content/test/test_3575.jpg
#   inflating: /content/test/test_3576.jpg
#   inflating: /content/test/test_3577.jpg
#   inflating: /content/test/test_3578.jpg
#   inflating: /content/test/test_3579.jpg
#   inflating: /content/test/test_3580.jpg
#   inflating: /content/test/test_3581.jpg
#   inflating: /content/test/test_3582.jpg
#   inflating: /content/test/test_3583.jpg
#   inflating: /content/test/test_3584.jpg
#   inflating: /content/test/test_3585.jpg
#   inflating: /content/test/test_3586.jpg
#   inflating: /content/test/test_3587.jpg
#   inflating: /content/test/test_3588.jpg
#   inflating: /content/test/test_3589.jpg
#   inflating: /content/test/test_3590.jpg
#   inflating: /content/test/test_3591.jpg
#   inflating: /content/test/test_3592.jpg
#   inflating: /content/test/test_3593.jpg
#   inflating: /content/test/test_3594.jpg
#   inflating: /content/test/test_3595.jpg
#   inflating: /content/test/test_3596.jpg
#   inflating: /content/test/test_3597.jpg
#   inflating: /content/test/test_3598.jpg
#   inflating: /content/test/test_3599.jpg
#   inflating: /content/test/test_3600.jpg
#   inflating: /content/test/test_3601.jpg
#   inflating: /content/test/test_3602.jpg
#   inflating: /content/test/test_3603.jpg
#   inflating: /content/test/test_3604.jpg
#   inflating: /content/test/test_3605.jpg
#   inflating: /content/test/test_3606.jpg
#   inflating: /content/test/test_3607.jpg
#   inflating: /content/test/test_3608.jpg
#   inflating: /content/test/test_3609.jpg
#   inflating: /content/test/test_3610.jpg
#   inflating: /content/test/test_3611.jpg
#   inflating: /content/test/test_3612.jpg
#   inflating: /content/test/test_3613.jpg
#   inflating: /content/test/test_3614.jpg
#   inflating: /content/test/test_3615.jpg
#   inflating: /content/test/test_3616.jpg
#   inflating: /content/test/test_3617.jpg
#   inflating: /content/test/test_3618.jpg
#   inflating: /content/test/test_3619.jpg
#   inflating: /content/test/test_3620.jpg
#   inflating: /content/test/test_3621.jpg
#   inflating: /content/test/test_3622.jpg
#   inflating: /content/test/test_3623.jpg
#   inflating: /content/test/test_3624.jpg
#   inflating: /content/test/test_3625.jpg
#   inflating: /content/test/test_3626.jpg
#   inflating: /content/test/test_3627.jpg
#   inflating: /content/test/test_3628.jpg
#   inflating: /content/test/test_3629.jpg
#   inflating: /content/test/test_3630.jpg
#   inflating: /content/test/test_3631.jpg
#   inflating: /content/test/test_3632.jpg
#   inflating: /content/test/test_3633.jpg
#   inflating: /content/test/test_3634.jpg
#   inflating: /content/test/test_3635.jpg
#   inflating: /content/test/test_3636.jpg
#   inflating: /content/test/test_3637.jpg
#   inflating: /content/test/test_3638.jpg
#   inflating: /content/test/test_3639.jpg
#   inflating: /content/test/test_3640.jpg
#   inflating: /content/test/test_3641.jpg
#   inflating: /content/test/test_3642.jpg
#   inflating: /content/test/test_3643.jpg
#   inflating: /content/test/test_3644.jpg
#   inflating: /content/test/test_3645.jpg
#   inflating: /content/test/test_3646.jpg
#   inflating: /content/test/test_3647.jpg
#   inflating: /content/test/test_3648.jpg
#   inflating: /content/test/test_3649.jpg
#   inflating: /content/test/test_3650.jpg
#   inflating: /content/test/test_3651.jpg
#   inflating: /content/test/test_3652.jpg
#   inflating: /content/test/test_3653.jpg
#   inflating: /content/test/test_3654.jpg
#   inflating: /content/test/test_3655.jpg
#   inflating: /content/test/test_3656.jpg
#   inflating: /content/test/test_3657.jpg
#   inflating: /content/test/test_3658.jpg
#   inflating: /content/test/test_3659.jpg
#   inflating: /content/test/test_3660.jpg
#   inflating: /content/test/test_3661.jpg
#   inflating: /content/test/test_3662.jpg
#   inflating: /content/test/test_3663.jpg
#   inflating: /content/test/test_3664.jpg
#   inflating: /content/test/test_3665.jpg
#   inflating: /content/test/test_3666.jpg
#   inflating: /content/test/test_3667.jpg
#   inflating: /content/test/test_3668.jpg
#   inflating: /content/test/test_3669.jpg
#   inflating: /content/test/test_3670.jpg
#   inflating: /content/test/test_3671.jpg
#   inflating: /content/test/test_3672.jpg
#   inflating: /content/test/test_3673.jpg
#   inflating: /content/test/test_3674.jpg
#   inflating: /content/test/test_3675.jpg
#   inflating: /content/test/test_3676.jpg
#   inflating: /content/test/test_3677.jpg
#   inflating: /content/test/test_3678.jpg
#   inflating: /content/test/test_3679.jpg
#   inflating: /content/test/test_3680.jpg
#   inflating: /content/test/test_3681.jpg
#   inflating: /content/test/test_3682.jpg
#   inflating: /content/test/test_3683.jpg
#   inflating: /content/test/test_3684.jpg
#   inflating: /content/test/test_3685.jpg
#   inflating: /content/test/test_3686.jpg
#   inflating: /content/test/test_3687.jpg
#   inflating: /content/test/test_3688.jpg
#   inflating: /content/test/test_3689.jpg
#   inflating: /content/test/test_3690.jpg
#   inflating: /content/test/test_3691.jpg
#   inflating: /content/test/test_3692.jpg
#   inflating: /content/test/test_3693.jpg
#   inflating: /content/test/test_3694.jpg
#   inflating: /content/test/test_3695.jpg
#   inflating: /content/test/test_3696.jpg
#   inflating: /content/test/test_3697.jpg
#   inflating: /content/test/test_3698.jpg
#   inflating: /content/test/test_3699.jpg
#   inflating: /content/test/test_3700.jpg
#   inflating: /content/test/test_3701.jpg
#   inflating: /content/test/test_3702.jpg
#   inflating: /content/test/test_3703.jpg
#   inflating: /content/test/test_3704.jpg
#   inflating: /content/test/test_3705.jpg
#   inflating: /content/test/test_3706.jpg
#   inflating: /content/test/test_3707.jpg
#   inflating: /content/test/test_3708.jpg
#   inflating: /content/test/test_3709.jpg
#   inflating: /content/test/test_3710.jpg
#   inflating: /content/test/test_3711.jpg
#   inflating: /content/test/test_3712.jpg
#   inflating: /content/test/test_3713.jpg
#   inflating: /content/test/test_3714.jpg
#   inflating: /content/test/test_3715.jpg
#   inflating: /content/test/test_3716.jpg
#   inflating: /content/test/test_3717.jpg
#   inflating: /content/test/test_3718.jpg
#   inflating: /content/test/test_3719.jpg
#   inflating: /content/test/test_3720.jpg
#   inflating: /content/test/test_3721.jpg
#   inflating: /content/test/test_3722.jpg
#   inflating: /content/test/test_3723.jpg
#   inflating: /content/test/test_3724.jpg
#   inflating: /content/test/test_3725.jpg
#   inflating: /content/test/test_3726.jpg
#   inflating: /content/test/test_3727.jpg
#   inflating: /content/test/test_3728.jpg
#   inflating: /content/test/test_3729.jpg
#   inflating: /content/test/test_3730.jpg
#   inflating: /content/test/test_3731.jpg
#   inflating: /content/test/test_3732.jpg
#   inflating: /content/test/test_3733.jpg
#   inflating: /content/test/test_3734.jpg
#   inflating: /content/test/test_3735.jpg
#   inflating: /content/test/test_3736.jpg
#   inflating: /content/test/test_3737.jpg
#   inflating: /content/test/test_3738.jpg
#   inflating: /content/test/test_3739.jpg
#   inflating: /content/test/test_3740.jpg
#   inflating: /content/test/test_3741.jpg
#   inflating: /content/test/test_3742.jpg
#   inflating: /content/test/test_3743.jpg
#   inflating: /content/test/test_3744.jpg
#   inflating: /content/test/test_3745.jpg
#   inflating: /content/test/test_3746.jpg
#   inflating: /content/test/test_3747.jpg
#   inflating: /content/test/test_3748.jpg
#   inflating: /content/test/test_3749.jpg
#   inflating: /content/test/test_3750.jpg
#   inflating: /content/test/test_3751.jpg
#   inflating: /content/test/test_3752.jpg
#   inflating: /content/test/test_3753.jpg
#   inflating: /content/test/test_3754.jpg
#   inflating: /content/test/test_3755.jpg
#   inflating: /content/test/test_3756.jpg
#   inflating: /content/test/test_3757.jpg
#   inflating: /content/test/test_3758.jpg
#   inflating: /content/test/test_3759.jpg
#   inflating: /content/test/test_3760.jpg
#   inflating: /content/test/test_3761.jpg
#   inflating: /content/test/test_3762.jpg
#   inflating: /content/test/test_3763.jpg
#   inflating: /content/test/test_3764.jpg
#   inflating: /content/test/test_3765.jpg
#   inflating: /content/test/test_3766.jpg
#   inflating: /content/test/test_3767.jpg
#   inflating: /content/test/test_3768.jpg
#   inflating: /content/test/test_3769.jpg
#   inflating: /content/test/test_3770.jpg
#   inflating: /content/test/test_3771.jpg
#   inflating: /content/test/test_3772.jpg
#   inflating: /content/test/test_3773.jpg
#   inflating: /content/test/test_3774.jpg
#   inflating: /content/test/test_3775.jpg
#   inflating: /content/test/test_3776.jpg
#   inflating: /content/test/test_3777.jpg
#   inflating: /content/test/test_3778.jpg
#   inflating: /content/test/test_3779.jpg
#   inflating: /content/test/test_3780.jpg
#   inflating: /content/test/test_3781.jpg
#   inflating: /content/test/test_3782.jpg
#   inflating: /content/test/test_3783.jpg
#   inflating: /content/test/test_3784.jpg
#   inflating: /content/test/test_3785.jpg
#   inflating: /content/test/test_3786.jpg
#   inflating: /content/test/test_3787.jpg
#   inflating: /content/test/test_3788.jpg
#   inflating: /content/test/test_3789.jpg
#   inflating: /content/test/test_3790.jpg
#   inflating: /content/test/test_3791.jpg
#   inflating: /content/test/test_3792.jpg
#   inflating: /content/test/test_3793.jpg
#   inflating: /content/test/test_3794.jpg
#   inflating: /content/test/test_3795.jpg
#   inflating: /content/test/test_3796.jpg
#   inflating: /content/test/test_3797.jpg
#   inflating: /content/test/test_3798.jpg
#   inflating: /content/test/test_3799.jpg
#   inflating: /content/test/test_3800.jpg
#   inflating: /content/test/test_3801.jpg
#   inflating: /content/test/test_3802.jpg
#   inflating: /content/test/test_3803.jpg
#   inflating: /content/test/test_3804.jpg
#   inflating: /content/test/test_3805.jpg
#   inflating: /content/test/test_3806.jpg
#   inflating: /content/test/test_3807.jpg
#   inflating: /content/test/test_3808.jpg
#   inflating: /content/test/test_3809.jpg
#   inflating: /content/test/test_3810.jpg
#   inflating: /content/test/test_3811.jpg
#   inflating: /content/test/test_3812.jpg
#   inflating: /content/test/test_3813.jpg
#   inflating: /content/test/test_3814.jpg
#   inflating: /content/test/test_3815.jpg
#   inflating: /content/test/test_3816.jpg
#   inflating: /content/test/test_3817.jpg
#   inflating: /content/test/test_3818.jpg
#   inflating: /content/test/test_3819.jpg
#   inflating: /content/test/test_3820.jpg
#   inflating: /content/test/test_3821.jpg
#   inflating: /content/test/test_3822.jpg
#   inflating: /content/test/test_3823.jpg
#   inflating: /content/test/test_3824.jpg
#   inflating: /content/test/test_3825.jpg
#   inflating: /content/test/test_3826.jpg
#   inflating: /content/test/test_3827.jpg
#   inflating: /content/test/test_3828.jpg
#   inflating: /content/test/test_3829.jpg
#   inflating: /content/test/test_3830.jpg
#   inflating: /content/test/test_3831.jpg
#   inflating: /content/test/test_3832.jpg
#   inflating: /content/test/test_3833.jpg
#   inflating: /content/test/test_3834.jpg
#   inflating: /content/test/test_3835.jpg
#   inflating: /content/test/test_3836.jpg
#   inflating: /content/test/test_3837.jpg
#   inflating: /content/test/test_3838.jpg
#   inflating: /content/test/test_3839.jpg
#   inflating: /content/test/test_3840.jpg
#   inflating: /content/test/test_3841.jpg
#   inflating: /content/test/test_3842.jpg
#   inflating: /content/test/test_3843.jpg
#   inflating: /content/test/test_3844.jpg
#   inflating: /content/test/test_3845.jpg
#   inflating: /content/test/test_3846.jpg
#   inflating: /content/test/test_3847.jpg
#   inflating: /content/test/test_3848.jpg
#   inflating: /content/test/test_3849.jpg
#   inflating: /content/test/test_3850.jpg
#   inflating: /content/test/test_3851.jpg
#   inflating: /content/test/test_3852.jpg
#   inflating: /content/test/test_3853.jpg
#   inflating: /content/test/test_3854.jpg
#   inflating: /content/test/test_3855.jpg
#   inflating: /content/test/test_3856.jpg
#   inflating: /content/test/test_3857.jpg
#   inflating: /content/test/test_3858.jpg
#   inflating: /content/test/test_3859.jpg
#   inflating: /content/test/test_3860.jpg
#   inflating: /content/test/test_3861.jpg
#   inflating: /content/test/test_3862.jpg
#   inflating: /content/test/test_3863.jpg
#   inflating: /content/test/test_3864.jpg
#   inflating: /content/test/test_3865.jpg
#   inflating: /content/test/test_3866.jpg
#   inflating: /content/test/test_3867.jpg
#   inflating: /content/test/test_3868.jpg
#   inflating: /content/test/test_3869.jpg
#   inflating: /content/test/test_3870.jpg
#   inflating: /content/test/test_3871.jpg
#   inflating: /content/test/test_3872.jpg
#   inflating: /content/test/test_3873.jpg
#   inflating: /content/test/test_3874.jpg
#   inflating: /content/test/test_3875.jpg
#   inflating: /content/test/test_3876.jpg
#   inflating: /content/test/test_3877.jpg
#   inflating: /content/test/test_3878.jpg
#   inflating: /content/test/test_3879.jpg
#   inflating: /content/test/test_3880.jpg
#   inflating: /content/test/test_3881.jpg
#   inflating: /content/test/test_3882.jpg
#   inflating: /content/test/test_3883.jpg
#   inflating: /content/test/test_3884.jpg
#   inflating: /content/test/test_3885.jpg
#   inflating: /content/test/test_3886.jpg
#   inflating: /content/test/test_3887.jpg
#   inflating: /content/train.csv
#   inflating: /content/train/train_0001.jpg
#   inflating: /content/train/train_0002.jpg
# ...
#   inflating: /content/train/train_3533.jpg
#   inflating: /content/train/train_3534.jpg
#   inflating: /content/train/train_3535.jpg
#   inflating: /content/train/train_3536.jpg
#   inflating: /content/train/train_3537.jpg
#   inflating: /content/train/train_3538.jpg
#   inflating: /content/train/train_3539.jpg
#   inflating: /content/train/train_3540.jpg
#   inflating: /content/train/train_3541.jpg
#   inflating: /content/train/train_3542.jpg
#   inflating: /content/train/train_3543.jpg
#   inflating: /content/train/train_3544.jpg
#   inflating: /content/train/train_3545.jpg
#   inflating: /content/train/train_3546.jpg
#   inflating: /content/train/train_3547.jpg
#   inflating: /content/train/train_3548.jpg
#   inflating: /content/train/train_3549.jpg
#   inflating: /content/train/train_3550.jpg
#   inflating: /content/train/train_3551.jpg
#   inflating: /content/train/train_3552.jpg
#   inflating: /content/train/train_3553.jpg
#   inflating: /content/train/train_3554.jpg
#   inflating: /content/train/train_3555.jpg
#   inflating: /content/train/train_3556.jpg
#   inflating: /content/train/train_3557.jpg
#   inflating: /content/train/train_3558.jpg
#   inflating: /content/train/train_3559.jpg
#   inflating: /content/train/train_3560.jpg
#   inflating: /content/train/train_3561.jpg
#   inflating: /content/train/train_3562.jpg
#   inflating: /content/train/train_3563.jpg
#   inflating: /content/train/train_3564.jpg
#   inflating: /content/train/train_3565.jpg
#   inflating: /content/train/train_3566.jpg
#   inflating: /content/train/train_3567.jpg
#   inflating: /content/train/train_3568.jpg
#   inflating: /content/train/train_3569.jpg
#   inflating: /content/train/train_3570.jpg
#   inflating: /content/train/train_3571.jpg
#   inflating: /content/train/train_3572.jpg
#   inflating: /content/train/train_3573.jpg
#   inflating: /content/train/train_3574.jpg
#   inflating: /content/train/train_3575.jpg
#   inflating: /content/train/train_3576.jpg
#   inflating: /content/train/train_3577.jpg
#   inflating: /content/train/train_3578.jpg
#   inflating: /content/train/train_3579.jpg
#   inflating: /content/train/train_3580.jpg
#   inflating: /content/train/train_3581.jpg
#   inflating: /content/train/train_3582.jpg
#   inflating: /content/train/train_3583.jpg
#   inflating: /content/train/train_3584.jpg
#   inflating: /content/train/train_3585.jpg
#   inflating: /content/train/train_3586.jpg
#   inflating: /content/train/train_3587.jpg
#   inflating: /content/train/train_3588.jpg
#   inflating: /content/train/train_3589.jpg
#   inflating: /content/train/train_3590.jpg
#   inflating: /content/train/train_3591.jpg
#   inflating: /content/train/train_3592.jpg
#   inflating: /content/train/train_3593.jpg
#   inflating: /content/train/train_3594.jpg
#   inflating: /content/train/train_3595.jpg
#   inflating: /content/train/train_3596.jpg
#   inflating: /content/train/train_3597.jpg
#   inflating: /content/train/train_3598.jpg
#   inflating: /content/train/train_3599.jpg
#   inflating: /content/train/train_3600.jpg
#   inflating: /content/train/train_3601.jpg
#   inflating: /content/train/train_3602.jpg
#   inflating: /content/train/train_3603.jpg
#   inflating: /content/train/train_3604.jpg
#   inflating: /content/train/train_3605.jpg
#   inflating: /content/train/train_3606.jpg
#   inflating: /content/train/train_3607.jpg
#   inflating: /content/train/train_3608.jpg
#   inflating: /content/train/train_3609.jpg
#   inflating: /content/train/train_3610.jpg
#   inflating: /content/train/train_3611.jpg
#   inflating: /content/train/train_3612.jpg
#   inflating: /content/train/train_3613.jpg
#   inflating: /content/train/train_3614.jpg
#   inflating: /content/train/train_3615.jpg
#   inflating: /content/train/train_3616.jpg
#   inflating: /content/train/train_3617.jpg
#   inflating: /content/train/train_3618.jpg
#   inflating: /content/train/train_3619.jpg
#   inflating: /content/train/train_3620.jpg
#   inflating: /content/train/train_3621.jpg
#   inflating: /content/train/train_3622.jpg
#   inflating: /content/train/train_3623.jpg
#   inflating: /content/train/train_3624.jpg
#   inflating: /content/train/train_3625.jpg
#   inflating: /content/train/train_3626.jpg
#   inflating: /content/train/train_3627.jpg
#   inflating: /content/train/train_3628.jpg
#   inflating: /content/train/train_3629.jpg
#   inflating: /content/train/train_3630.jpg
#   inflating: /content/train/train_3631.jpg
#   inflating: /content/train/train_3632.jpg
#   inflating: /content/train/train_3633.jpg
#   inflating: /content/train/train_3634.jpg
#   inflating: /content/train/train_3635.jpg
#   inflating: /content/train/train_3636.jpg
#   inflating: /content/train/train_3637.jpg
#   inflating: /content/train/train_3638.jpg
#   inflating: /content/train/train_3639.jpg
#   inflating: /content/train/train_3640.jpg
#   inflating: /content/train/train_3641.jpg
#   inflating: /content/train/train_3642.jpg
#   inflating: /content/train/train_3643.jpg
#   inflating: /content/train/train_3644.jpg
#   inflating: /content/train/train_3645.jpg
#   inflating: /content/train/train_3646.jpg
#   inflating: /content/train/train_3647.jpg
#   inflating: /content/train/train_3648.jpg
#   inflating: /content/train/train_3649.jpg
#   inflating: /content/train/train_3650.jpg
#   inflating: /content/train/train_3651.jpg
#   inflating: /content/train/train_3652.jpg
#   inflating: /content/train/train_3653.jpg
#   inflating: /content/train/train_3654.jpg
#   inflating: /content/train/train_3655.jpg
#   inflating: /content/train/train_3656.jpg
#   inflating: /content/train/train_3657.jpg
#   inflating: /content/train/train_3658.jpg
#   inflating: /content/train/train_3659.jpg
#   inflating: /content/train/train_3660.jpg
#   inflating: /content/train/train_3661.jpg
#   inflating: /content/train/train_3662.jpg
#   inflating: /content/train/train_3663.jpg
#   inflating: /content/train/train_3664.jpg
#   inflating: /content/train/train_3665.jpg
#   inflating: /content/train/train_3666.jpg
#   inflating: /content/train/train_3667.jpg
#   inflating: /content/train/train_3668.jpg
#   inflating: /content/train/train_3669.jpg
#   inflating: /content/train/train_3670.jpg
#   inflating: /content/train/train_3671.jpg
#   inflating: /content/train/train_3672.jpg
#   inflating: /content/train/train_3673.jpg
#   inflating: /content/train/train_3674.jpg
#   inflating: /content/train/train_3675.jpg
#   inflating: /content/train/train_3676.jpg
#   inflating: /content/train/train_3677.jpg
#   inflating: /content/train/train_3678.jpg
#   inflating: /content/train/train_3679.jpg
#   inflating: /content/train/train_3680.jpg
#   inflating: /content/train/train_3681.jpg
#   inflating: /content/train/train_3682.jpg
#   inflating: /content/train/train_3683.jpg
#   inflating: /content/train/train_3684.jpg
#   inflating: /content/train/train_3685.jpg
#   inflating: /content/train/train_3686.jpg
#   inflating: /content/train/train_3687.jpg
#   inflating: /content/train/train_3688.jpg
#   inflating: /content/train/train_3689.jpg
#   inflating: /content/train/train_3690.jpg
#   inflating: /content/train/train_3691.jpg
#   inflating: /content/train/train_3692.jpg
#   inflating: /content/train/train_3693.jpg
#   inflating: /content/train/train_3694.jpg
#   inflating: /content/train/train_3695.jpg
#   inflating: /content/train/train_3696.jpg
#   inflating: /content/train/train_3697.jpg
#   inflating: /content/train/train_3698.jpg
#   inflating: /content/train/train_3699.jpg
#   inflating: /content/train/train_3700.jpg
#   inflating: /content/train/train_3701.jpg
#   inflating: /content/train/train_3702.jpg
#   inflating: /content/train/train_3703.jpg
#   inflating: /content/train/train_3704.jpg
#   inflating: /content/train/train_3705.jpg
#   inflating: /content/train/train_3706.jpg
#   inflating: /content/train/train_3707.jpg
#   inflating: /content/train/train_3708.jpg
#   inflating: /content/train/train_3709.jpg
#   inflating: /content/train/train_3710.jpg
#   inflating: /content/train/train_3711.jpg
#   inflating: /content/train/train_3712.jpg
#   inflating: /content/train/train_3713.jpg
#   inflating: /content/train/train_3714.jpg
#   inflating: /content/train/train_3715.jpg
#   inflating: /content/train/train_3716.jpg
#   inflating: /content/train/train_3717.jpg
#   inflating: /content/train/train_3718.jpg
#   inflating: /content/train/train_3719.jpg
#   inflating: /content/train/train_3720.jpg
#   inflating: /content/train/train_3721.jpg
#   inflating: /content/train/train_3722.jpg
#   inflating: /content/train/train_3723.jpg
#   inflating: /content/train/train_3724.jpg
#   inflating: /content/train/train_3725.jpg
#   inflating: /content/train/train_3726.jpg
#   inflating: /content/train/train_3727.jpg
#   inflating: /content/train/train_3728.jpg
#   inflating: /content/train/train_3729.jpg
#   inflating: /content/train/train_3730.jpg
#   inflating: /content/train/train_3731.jpg
#   inflating: /content/train/train_3732.jpg
#   inflating: /content/train/train_3733.jpg
#   inflating: /content/train/train_3734.jpg
#   inflating: /content/train/train_3735.jpg
#   inflating: /content/train/train_3736.jpg
#   inflating: /content/train/train_3737.jpg
#   inflating: /content/train/train_3738.jpg
#   inflating: /content/train/train_3739.jpg
#   inflating: /content/train/train_3740.jpg
#   inflating: /content/train/train_3741.jpg
#   inflating: /content/train/train_3742.jpg
#   inflating: /content/train/train_3743.jpg
#   inflating: /content/train/train_3744.jpg
#   inflating: /content/train/train_3745.jpg
#   inflating: /content/train/train_3746.jpg
#   inflating: /content/train/train_3747.jpg
#   inflating: /content/train/train_3748.jpg
#   inflating: /content/train/train_3749.jpg
#   inflating: /content/train/train_3750.jpg
#   inflating: /content/train/train_3751.jpg
#   inflating: /content/train/train_3752.jpg
#   inflating: /content/train/train_3753.jpg
#   inflating: /content/train/train_3754.jpg
#   inflating: /content/train/train_3755.jpg
#   inflating: /content/train/train_3756.jpg
#   inflating: /content/train/train_3757.jpg
#   inflating: /content/train/train_3758.jpg
#   inflating: /content/train/train_3759.jpg
#   inflating: /content/train/train_3760.jpg
#   inflating: /content/train/train_3761.jpg
#   inflating: /content/train/train_3762.jpg
#   inflating: /content/train/train_3763.jpg
#   inflating: /content/train/train_3764.jpg
#   inflating: /content/train/train_3765.jpg
#   inflating: /content/train/train_3766.jpg
#   inflating: /content/train/train_3767.jpg
#   inflating: /content/train/train_3768.jpg
#   inflating: /content/train/train_3769.jpg
#   inflating: /content/train/train_3770.jpg
#   inflating: /content/train/train_3771.jpg
#   inflating: /content/train/train_3772.jpg
#   inflating: /content/train/train_3773.jpg
#   inflating: /content/train/train_3774.jpg
#   inflating: /content/train/train_3775.jpg
#   inflating: /content/train/train_3776.jpg
#   inflating: /content/train/train_3777.jpg
#   inflating: /content/train/train_3778.jpg
#   inflating: /content/train/train_3779.jpg
#   inflating: /content/train/train_3780.jpg
#   inflating: /content/train/train_3781.jpg
#   inflating: /content/train/train_3782.jpg
#   inflating: /content/train/train_3783.jpg
#   inflating: /content/train/train_3784.jpg
#   inflating: /content/train/train_3785.jpg
#   inflating: /content/train/train_3786.jpg
#   inflating: /content/train/train_3787.jpg
#   inflating: /content/train/train_3788.jpg
#   inflating: /content/train/train_3789.jpg
#   inflating: /content/train/train_3790.jpg
#   inflating: /content/train/train_3791.jpg
#   inflating: /content/train/train_3792.jpg
#   inflating: /content/train/train_3793.jpg
#   inflating: /content/train/train_3794.jpg
#   inflating: /content/train/train_3795.jpg
#   inflating: /content/train/train_3796.jpg
#   inflating: /content/train/train_3797.jpg
#   inflating: /content/train/train_3798.jpg
#   inflating: /content/train/train_3799.jpg
#   inflating: /content/train/train_3800.jpg
#   inflating: /content/train/train_3801.jpg
#   inflating: /content/train/train_3802.jpg
#   inflating: /content/train/train_3803.jpg
#   inflating: /content/train/train_3804.jpg
#   inflating: /content/train/train_3805.jpg
#   inflating: /content/train/train_3806.jpg
#   inflating: /content/train/train_3807.jpg
#   inflating: /content/train/train_3808.jpg
#   inflating: /content/train/train_3809.jpg
#   inflating: /content/train/train_3810.jpg
#   inflating: /content/train/train_3811.jpg
#   inflating: /content/train/train_3812.jpg
#   inflating: /content/train/train_3813.jpg
#   inflating: /content/train/train_3814.jpg
#   inflating: /content/train/train_3815.jpg
#   inflating: /content/train/train_3816.jpg
#   inflating: /content/train/train_3817.jpg
#   inflating: /content/train/train_3818.jpg
#   inflating: /content/train/train_3819.jpg
#   inflating: /content/train/train_3820.jpg
#   inflating: /content/train/train_3821.jpg
#   inflating: /content/train/train_3822.jpg
#   inflating: /content/train/train_3823.jpg
#   inflating: /content/train/train_3824.jpg
#   inflating: /content/train/train_3825.jpg
#   inflating: /content/train/train_3826.jpg
#   inflating: /content/train/train_3827.jpg
#   inflating: /content/train/train_3828.jpg
#   inflating: /content/train/train_3829.jpg
#   inflating: /content/train/train_3830.jpg
#   inflating: /content/train/train_3831.jpg
#   inflating: /content/train/train_3832.jpg
#   inflating: /content/train/train_3833.jpg
#   inflating: /content/train/train_3834.jpg
#   inflating: /content/train/train_3835.jpg
#   inflating: /content/train/train_3836.jpg
#   inflating: /content/train/train_3837.jpg
#   inflating: /content/train/train_3838.jpg
#   inflating: /content/train/train_3839.jpg
#   inflating: /content/train/train_3840.jpg
#   inflating: /content/train/train_3841.jpg
#   inflating: /content/train/train_3842.jpg
#   inflating: /content/train/train_3843.jpg
#   inflating: /content/train/train_3844.jpg
#   inflating: /content/train/train_3845.jpg
#   inflating: /content/train/train_3846.jpg
#   inflating: /content/train/train_3847.jpg
#   inflating: /content/train/train_3848.jpg
#   inflating: /content/train/train_3849.jpg
#   inflating: /content/train/train_3850.jpg
#   inflating: /content/train/train_3851.jpg
#   inflating: /content/train/train_3852.jpg
#   inflating: /content/train/train_3853.jpg
#   inflating: /content/train/train_3854.jpg
#   inflating: /content/train/train_3855.jpg
#   inflating: /content/train/train_3856.jpg
#   inflating: /content/train/train_3857.jpg
#   inflating: /content/train/train_3858.jpg
#   inflating: /content/train/train_3859.jpg
#   inflating: /content/train/train_3860.jpg
#   inflating: /content/train/train_3861.jpg
#   inflating: /content/train/train_3862.jpg
#   inflating: /content/train/train_3863.jpg
#   inflating: /content/train/train_3864.jpg
#   inflating: /content/train/train_3865.jpg
#   inflating: /content/train/train_3866.jpg
#   inflating: /content/train/train_3867.jpg
#   inflating: /content/train/train_3868.jpg
#   inflating: /content/train/train_3869.jpg
#   inflating: /content/train/train_3870.jpg
#   inflating: /content/train/train_3871.jpg
#   inflating: /content/train/train_3872.jpg
#   inflating: /content/train/train_3873.jpg
#   inflating: /content/train/train_3874.jpg
#   inflating: /content/train/train_3875.jpg
#   inflating: /content/train/train_3876.jpg
#   inflating: /content/train/train_3877.jpg
#   inflating: /content/train/train_3878.jpg
#   inflating: /content/train/train_3879.jpg
#   inflating: /content/train/train_3880.jpg
#   inflating: /content/train/train_3881.jpg
#   inflating: /content/train/train_3882.jpg
#   inflating: /content/train/train_3883.jpg
#   inflating: /content/train/train_3884.jpg
#   inflating: /content/train/train_3885.jpg
#   inflating: /content/train/train_3886.jpg
#   inflating: /content/train/train_3887.jpg

# %%
# Pillow 오류 방지용 버전 명시 포함
# !pip install --upgrade --force-reinstall Pillow==10.4.0

# %% [markdown]
# # 라이브러리, 데이터, 설정

# %%
import os, re, math, random
import pandas as pd
from PIL import Image
from torch.utils.data import Dataset, DataLoader
from dataclasses import dataclass
import torch
from typing import Dict, List, Any

# 이미지 로드 시 픽셀 제한 해제
Image.MAX_IMAGE_PIXELS = None

# 디바이스 GPU 우선 사용 설정
device = "cuda" if torch.cuda.is_available() else "cpu"
print("Device:", device)

# 사전 학습 모델 정의
MODEL_ID = "Qwen/Qwen3-VL-4B-Instruct"   # ✅ Qwen3-VL-4B 사용
IMAGE_SIZE = 448   # ✅ 해상도 값 448로 높임
MAX_NEW_TOKENS = 8
SEED = 42
random.seed(SEED); torch.manual_seed(SEED); torch.cuda.manual_seed_all(SEED)

# dtype: bf16 지원 시 bf16, 아니면 fp16 (셀 2에서 모델 로드시 사용)
amp_dtype = torch.bfloat16 if torch.cuda.is_bf16_supported() else torch.float16

# 데이터셋 로드
train_df = pd.read_csv("/content/train.csv")
test_df  = pd.read_csv("/content/test.csv")

# ✅학습데이터 400개 
train_df = train_df.sample(n=400, random_state=SEED).reset_index(drop=True)

print(f"train_df: {len(train_df)}, test_df: {len(test_df)}")
# Out:
# Device: cuda
# train_df: 400, test_df: 3887

# %%
# === Utils: 프롬프트/선지 파싱/TTA ===
import torch, os
from collections import Counter
from PIL import Image

def extract_choice(text: str) -> str:
    text = (text or "").strip().upper()
    # 끝 글자 우선
    if text and text[-1] in "ABCD":
        return text[-1]
    # 마지막 라인 스캔
    lines = [l.strip().upper() for l in text.splitlines() if l.strip()]
    if lines:
        last = lines[-1]
        for tok in ("A","B","C","D"):
            if tok in last: return tok
    # 전체 스캔
    for tok in ("A","B","C","D"):
        if tok in text: return tok
    return "A"  # fallback

def build_mc_prompt(q, a, b, c, d):
    return (
        "[문제]\n"
        f"{q}\n\n"
        "[보기]\n"
        f"A) {a}\nB) {b}\nC) {c}\nD) {d}\n\n"
        "형식: 한 글자만 답하라.\n정답:"
    )

@torch.no_grad()
def generate_choice(model, processor, image, prompt, max_new_tokens=4):
    model.eval()
    inputs = processor(text=prompt, images=image, return_tensors="pt").to(model.device)
    out_ids = model.generate(
        **inputs,
        max_new_tokens=max_new_tokens,
        do_sample=False,
        temperature=0.0,
        repetition_penalty=1.0
    )
    out = processor.batch_decode(out_ids, skip_special_tokens=True)[0]
    tail = out[-16:]
    return extract_choice(tail)

def tta_predict_choices(model, processor, image, prompt):
    # 좌우반전 한 번 TTA (다수결)
    from PIL import ImageOps
    p1 = generate_choice(model, processor, image, prompt)
    p2 = generate_choice(model, processor, ImageOps.mirror(image), prompt)
    return Counter([p1, p2]).most_common(1)[0][0]

# %% [markdown]
# # 모델, Processor
#
# 7.5GB 정도의 모델 다운로드가 진행됩니다. 10~20분 정도가 소요됩니다.
#
# #### 실습 참고 내용
#
#     챕터 5-1 PEFT(파라미터 효율적 튜닝)
#     - LoRA 구현 : LoraConfig()

# %%
# === EMA(지수이동평균) ===
class EMAHelper:
    def __init__(self, model, decay=0.999):
        self.decay = decay
        self.shadow = {}
        for n, p in model.named_parameters():
            if p.requires_grad:
                self.shadow[n] = p.detach().clone()

    @torch.no_grad()
    def update(self, model):
        for n, p in model.named_parameters():
            if p.requires_grad:
                self.shadow[n].mul_(self.decay).add_(p.detach(), alpha=1.0 - self.decay)

    @torch.no_grad()
    def swap_to_ema(self, model):
        # 현재 ↔ EMA 가중치 스왑 (두 번 호출하면 원복)
        for n, p in model.named_parameters():
            if p.requires_grad:
                tmp = p.detach().clone()
                p.data.copy_(self.shadow[n].data)
                self.shadow[n] = tmp

# === Validation: 객관식 정확도 ===
@torch.no_grad()
def evaluate_mc_accuracy(model, processor, valid_df, use_tta=False, progress=False):
    model.eval()
    N = len(valid_df)
    correct = 0
    it = range(N)
    if progress:
        try:
            from tqdm.auto import tqdm
            it = tqdm(it, total=N, desc="Validate", unit="sample")
        except Exception:
            pass

    for i in it:
        row = valid_df.iloc[i]
        img = Image.open(row["path"]).convert("RGB")
        prompt = build_mc_prompt(row["question"], row["a"], row["b"], row["c"], row["d"])
        pred = tta_predict_choices(model, processor, img, prompt) if use_tta else generate_choice(model, processor, img, prompt)
        gt = str(row["answer"]).strip().upper()  # ← 정답 컬럼명 다르면 여기만 수정
        correct += (pred == gt)
    return correct / max(1, N)

# %%
from transformers import (
    AutoModelForVision2Seq,
    AutoProcessor,
    BitsAndBytesConfig,
)
from peft import LoraConfig, get_peft_model, prepare_model_for_kbit_training

# 양자화: 4bit NF4
bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_use_double_quant=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=amp_dtype,   # 셀1에서 정의한 amp_dtype 사용
)

# 프로세서 (이미지 해상도 고정: 448x448)
processor = AutoProcessor.from_pretrained(
    MODEL_ID,
    min_pixels=IMAGE_SIZE * IMAGE_SIZE,
    max_pixels=IMAGE_SIZE * IMAGE_SIZE,
    trust_remote_code=True,
)

# 사전학습 모델 (4bit 로드 + dtype 지정 + device map)
base_model = AutoModelForVision2Seq.from_pretrained(
    MODEL_ID,
    quantization_config=bnb_config,
    torch_dtype=amp_dtype,
    device_map="auto",
    trust_remote_code=True,
)

# 체크포인트/메모리 안정화
base_model.config.use_cache = False
base_model = prepare_model_for_kbit_training(base_model)
base_model.gradient_checkpointing_enable()

# LoRA 세팅 ✅
# - 학습데이터 400개에 epoch 2를 기준으로 LoRA 세팅 값을 조절
# LoRA 세팅 ✅
# - 학습데이터 400개, epoch 2 기준으로 최적화된 설정
# - 목표: 메모리 절약(T4 12GB) + 안정적인 수렴 + 과적합 방지

lora_config = LoraConfig(
    r=16,                               # 🔹 랭크(rank)
    # LoRA의 저랭크 행렬 차원 크기. r이 클수록 표현력 ↑, 메모리/시간 부담 ↑
    # 일반적으로 4~16 사이에서 조정. r=16은 중간 이상 수준으로 성능 향상 기대 가능.

    lora_alpha=32,                      # 🔹 LoRA 스케일링 계수
    # LoRA의 학습된 가중치(ΔW)를 얼마나 크게 반영할지 결정.
    # α/r 비율이 학습 효과를 조절함 → 여기선 32/16=2로 안정적이며 과적합 위험 낮음.

    lora_dropout=0.05,                  # 🔹 드롭아웃 비율
    # LoRA 가중치 업데이트 시 일부를 랜덤 무시(regularization).
    # 0.05는 적당히 낮은 확률로, 과적합 방지 + 미세조정 안정성 향상.

    bias="none",                        # 🔹 bias 학습 여부
    # 기존 모델의 bias는 그대로 두고, LoRA 레이어만 학습.
    # 파라미터 수를 줄여 메모리 절약 및 학습 안정성 확보.

    target_modules=[                    # 🔹 적용 대상 모듈
        "q_proj","k_proj","v_proj",     # → Attention의 Query, Key, Value projection
        "o_proj",                       # → Attention Output projection
        "gate_proj","up_proj","down_proj" # → FFN(피드포워드 네트워크) 부분
    ],
    # 핵심 연산 모듈(QKV + FFN)에만 LoRA 적용 → 효율적 미세조정
    # 전체 파라미터 중 0.1~1%만 학습하면서도 원본 모델 성능 대부분 유지 가능.

    task_type="CAUSAL_LM",              # 🔹 작업 유형 'Causal Language Model'용 설정.
)


# PEFT 모델 생성
model = get_peft_model(base_model, lora_config)
model.print_trainable_parameters()

print("✅ Qwen3-VL-4B 4bit + LoRA 준비 완료")
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# preprocessor_config.json:   0%|          | 0.00/390 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# video_preprocessor_config.json:   0%|          | 0.00/385 [00:00<?, ?B/s]
# chat_template.json: 0.00B [00:00, ?B/s]
# /usr/local/lib/python3.12/dist-packages/transformers/models/auto/modeling_auto.py:2284: FutureWarning: The class `AutoModelForVision2Seq` is deprecated and will be removed in v5.0. Please use `AutoModelForImageTextToText` instead.
#   warnings.warn(
# config.json: 0.00B [00:00, ?B/s]
# `torch_dtype` is deprecated! Use `dtype` instead!
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Fetching 2 files:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/4.97G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/3.91G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/269 [00:00<?, ?B/s]
# trainable params: 33,030,144 || all params: 4,470,845,952 || trainable%: 0.7388
# ✅ Qwen3-VL-4B 4bit + LoRA 준비 완료

# %% [markdown]
# # 프롬프트 템플릿
#
# #### 실습 참고 내용
#
#     챕터 5-1 PEFT(파라미터 효율적 튜닝)
#     - 프롬프트 템플릿 : convert_to_chatml(), formatting_prompts_func()

# %%
# ✅ 학습률을 높이기 위해 지시사항과 프롬프트 영문으로 바꿈

# 모델 지시사항
SYSTEM_INSTRUCT = (
    "You are a smart and accurate visual question answering assistant. "
    "Carefully look at the image and understand the question before answering. "
    "Answer using exactly one letter among a, b, c, or d, without any explanation."
)

# 프롬프트
def build_mc_prompt(question, a, b, c, d):
    return (
        f"{question}\n"
        f"(a) {a}\n(b) {b}\n(c) {c}\n(d) {d}\n\n"
        "Answer only with one lowercase letter among a, b, c, or d. Do not include any other words."
    )

# %% [markdown]
# # Custom Dataset, Collator
#
# #### 실습 참고 내용
#
#     챕터 1-2 MLP 구현
#     - TensorDataset()
#
#     챕터 5-2 데이터 생성 및 파인튜닝 (향후 학습 분량)
#     - IntentDataset()

# %%
# 커스텀 데이터셋
class VQAMCDataset(Dataset):
    def __init__(self, df, processor, train=True):
        self.df = df.reset_index(drop=True)
        self.processor = processor
        self.train = train

    def __len__(self): return len(self.df)

    def __getitem__(self, i):
        row = self.df.iloc[i]
        img = Image.open(row["path"]).convert("RGB")

        q = str(row["question"])
        a, b, c, d = str(row["a"]), str(row["b"]), str(row["c"]), str(row["d"])
        user_text = build_mc_prompt(q, a, b, c, d)

        messages = [
            {"role":"system","content":[{"type":"text","text":SYSTEM_INSTRUCT}]},
            {"role":"user","content":[
                {"type":"image","image":img},
                {"type":"text","text":user_text}
            ]}
        ]
        if self.train:
            gold = str(row["answer"]).strip().lower()
            messages.append({"role":"assistant","content":[{"type":"text","text":gold}]})

        return {"messages": messages, "image": img}

# 데이터 콜레이터
@dataclass
class DataCollator:
    processor: Any
    train: bool = True

    def __call__(self, batch):
        texts, images = [], []
        for sample in batch:
            messages = sample["messages"]
            img = sample["image"]

            text = self.processor.apply_chat_template(
                messages,
                tokenize=False,
                add_generation_prompt=False
            )
            texts.append(text)
            images.append(img)

        enc = self.processor(
            text=texts,
            images=images,
            padding=True,
            return_tensors="pt"
        )

        if self.train:
            enc["labels"] = enc["input_ids"].clone()

        return enc

# %% [markdown]
# # DataLoader
#
# #### 실습 참고 내용
#
#     챕터 3-1 Transfer Learning 기반의 CNN 모델 학습
#     - 데이터로더 정의 : DataLoader()

# %%
# ===== DataLoader & Optimizer/Scheduler (중복 제거 버전) =====
# NOTE: DataLoader 임포트/amp_dtype 정의는 앞 셀에서 이미 했으니 여기서는 생략

# 검증용 데이터 분리
split = int(len(train_df) * 0.9)
train_subset, valid_subset = train_df.iloc[:split], train_df.iloc[split:]

# VQAMCDataset 형태로 변환
train_ds = VQAMCDataset(train_subset, processor, train=True)
valid_ds = VQAMCDataset(valid_subset, processor, train=True)

# ===== Fast LoRA config (T4 12GB, ~20분 내) =====
# 🔹 목표: 제한된 GPU 메모리(12GB)에서 빠르고 안정적인 LoRA 학습 수행
# 🔹 특징: 적은 데이터셋(약 400개) + 2 epoch 기준으로 효율적으로 수렴하도록 설정

BATCH_SIZE   = 1            # ✅ DataLoader에서 한 번에 불러올 샘플 개수
# VRAM 절약용 최소 배치. 메모리 사용량 ↓ 대신, 아래 GRAD_ACCUM으로 유효 배치 크기를 키워 안정성 보완.
GRAD_ACCUM   = 8            # ✅ Gradient Accumulation Steps
# 그래디언트를 8번 누적한 뒤 한 번 optimizer step 수행.
# 유효 배치 크기 = 1(batch) × 8(accum) = 8 → 메모리는 적게 쓰면서 큰 배치 효과(더 부드러운 학습)를 얻음.
EPOCHS       = 2            # ✅ 전 400개의 데이터 기준으로 과적합 위험을 낮추면서 충분히 수렴.
MAX_STEPS    = 240          # ✅ # EPOCHS보다 우선 적용 → 240 step 도달 시 학습 종료.
LR           = 2e-4         # ✅ 학습률 (Learning Rate) 2e-4는 속도와 안정성 사이의 균형값 → 빠르게 수렴하면서 폭주 위험 낮음.
WEIGHT_DECAY = 0.01         # ✅ L2 정규화 계수
# 가중치가 과도하게 커지는 걸 방지 (overfitting 억제). 일반적인 Transformer의 표준값 (0.01).
WARMUP_STEPS = 20           # ✅ Learning Rate Warmup 단계 수
# 초반 20 step 동안 학습률을 선형 증가시켜 모델 예열. 갑작스런 큰 학습률로 인한 불안정한 손실 폭주 방지.
MAX_NORM     = 1.0          # ✅ Gradient Clipping 최대 노름 값
# 그래디언트 폭주 방지 (Exploding Gradient). norm이 1.0을 넘으면 잘라내서 안정적 업데이트 보장.
SEED         = 42           # ✅ 랜덤 시드 고정 (재현성)
# 데이터 셔플, weight 초기화 등의 무작위성을 통제. 실험 결과를 반복해도 동일하게 재현 가능.


# 성능 옵션
torch.backends.cuda.matmul.allow_tf32 = True
torch.backends.cudnn.benchmark = True

train_loader = DataLoader(
    train_ds,
    batch_size=BATCH_SIZE,
    shuffle=True,
    collate_fn=DataCollator(processor, True),
    pin_memory=True,  # CUDA일 때만 True로 바꾸고 싶으면: (device=="cuda")
)

valid_loader = DataLoader(
    valid_ds,
    batch_size=BATCH_SIZE * 2,  # 검증은 grad 없음 → 배치 2배 가능
    shuffle=False,
    collate_fn=DataCollator(processor, True),
    pin_memory=True,
)

# ----- Optimizer / Scheduler -----
from torch.optim import AdamW
from transformers import get_cosine_schedule_with_warmup

optimizer = AdamW(model.parameters(), lr=LR, weight_decay=WEIGHT_DECAY)
scheduler = get_cosine_schedule_with_warmup(
    optimizer,
    num_warmup_steps=WARMUP_STEPS,
    num_training_steps=MAX_STEPS // max(1, GRAD_ACCUM) + WARMUP_STEPS,
)

print(f"[Info] train_batches={len(train_loader)}, valid_batches={len(valid_loader)}")
# Out:
# [Info] train_batches=360, valid_batches=20

# %% [markdown]
# # fine-tuning
#
# - 200개만 학습 : 10~20분 소요
#
# #### 실습 참고 내용
#
#     챕터 1-2 MLP 구현
#     - 모델 정의 : SimpleMLP(), SequentialMLP()
#
#     챕터 3-1 Transfer Learning 기반의 CNN 모델 학습
#     - 학습 루프 : 문제 6: 모델 학습을 위한 반복문
#     - 추론 : with torch.no_grad(), model.eval()

# %%
# ===== Fine-tuning Loop (중복 제거 버전) =====
import math, torch
from tqdm.auto import tqdm

# GradScaler: fp16일 때만 활성화 (bf16이면 비활성)
use_fp16_scaler = (torch.cuda.is_available() and amp_dtype == torch.float16)
scaler = torch.cuda.amp.GradScaler(enabled=use_fp16_scaler)

# 모델은 이미 device_map="auto"로 로드됨 → model.to(...) 호출하지 않음
model.train()
global_step = 0

print(f"Starting training with amp_dtype={amp_dtype}, "
      f"epochs={EPOCHS}, max_steps={MAX_STEPS}, grad_accum={GRAD_ACCUM}")

for epoch in range(1, EPOCHS + 1):
    running_loss = 0.0
    progress = tqdm(train_loader, desc=f"Epoch {epoch} [train]", unit="batch")

    optimizer.zero_grad(set_to_none=True)
    for step, batch in enumerate(progress, start=1):
        if global_step >= MAX_STEPS:
            break

        # 텐서만 모델의 디바이스로 이동
        batch = {k: (v.to(model.device, non_blocking=True) if isinstance(v, torch.Tensor) else v)
                 for k, v in batch.items()}

        # AMP 전방/역전파
        with torch.autocast(device_type="cuda", dtype=amp_dtype, enabled=torch.cuda.is_available()):
            outputs = model(**batch)
            loss = outputs.loss
            if GRAD_ACCUM > 1:
                loss = loss / GRAD_ACCUM

        if use_fp16_scaler:
            scaler.scale(loss).backward()
        else:
            loss.backward()

        # grad accumulation
        if step % GRAD_ACCUM == 0:
            # gradient clipping
            if use_fp16_scaler:
                scaler.unscale_(optimizer)
            torch.nn.utils.clip_grad_norm_(model.parameters(), MAX_NORM)

            # optimizer / scheduler step
            if use_fp16_scaler:
                scaler.step(optimizer)
                scaler.update()
            else:
                optimizer.step()
            optimizer.zero_grad(set_to_none=True)
            scheduler.step()

            global_step += 1
            progress.set_postfix({"loss": f"{(loss.item() * GRAD_ACCUM):.4f}", "gs": global_step})

        running_loss += float(loss)

    # 조기 종료 조건
    if global_step >= MAX_STEPS:
        print(f"⏹️ Reached MAX_STEPS={MAX_STEPS}. Stopping.")
        break

    # ===== Validation =====
    model.eval()
    val_loss, val_steps = 0.0, 0
    with torch.no_grad():
        for vb in tqdm(valid_loader, desc=f"Epoch {epoch} [valid]", unit="batch"):
            vb = {k: (v.to(model.device, non_blocking=True) if isinstance(v, torch.Tensor) else v)
                  for k, v in vb.items()}
            with torch.autocast(device_type="cuda", dtype=amp_dtype, enabled=torch.cuda.is_available()):
                out = model(**vb)
                vloss = out.loss if hasattr(out, "loss") and out.loss is not None else 0.0
            val_loss += float(vloss)
            val_steps += 1

    mean_vloss = val_loss / max(val_steps, 1)
    print(f"[Epoch {epoch}] valid loss: {mean_vloss:.4f}")
    model.train()

# ===== 저장 (LoRA 어댑터 + processor) =====
SAVE_DIR = "/content/qwen3_vl_4b_lora"
model.save_pretrained(SAVE_DIR)      
processor.save_pretrained(SAVE_DIR)
print("✅ Saved to:", SAVE_DIR)
# Out:
# Starting training with amp_dtype=torch.bfloat16, epochs=2, max_steps=240, grad_accum=8
# /tmp/ipython-input-3465423891.py:7: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler(enabled=use_fp16_scaler)
# Epoch 1 [train]:   0%|          | 0/360 [00:00<?, ?batch/s]
# /usr/local/lib/python3.12/dist-packages/torch/utils/checkpoint.py:85: UserWarning: None of the inputs have requires_grad=True. Gradients will be None
#   warnings.warn(
# /tmp/ipython-input-3465423891.py:60: UserWarning: Converting a tensor with requires_grad=True to a scalar may lead to unexpected behavior.
# Consider using tensor.detach() first. (Triggered internally at /pytorch/torch/csrc/autograd/generated/python_variable_methods.cpp:836.)
#   running_loss += float(loss)
# Epoch 1 [valid]:   0%|          | 0/20 [00:00<?, ?batch/s]
# [Epoch 1] valid loss: 4.8559
# Epoch 2 [train]:   0%|          | 0/360 [00:00<?, ?batch/s]
# Epoch 2 [valid]:   0%|          | 0/20 [00:00<?, ?batch/s]
# [Epoch 2] valid loss: 4.9018
# ✅ Saved to: /content/qwen3_vl_4b_lora

# %% [markdown]
# # inference
#
# 30분~1시간 소요
#
# #### 실습 참고 내용
#
#     챕터4-1 RAG 기반 Customer Service AI 에이전트 개발
#     - 데이터 파서 : langchain_core.output_parsers(), StrOutputParser()
#
#     챕터 3-1 Transfer Learning 기반의 CNN 모델 학습
#     - 학습 루프 : 문제 6: 모델 학습을 위한 반복문
#     - 추론 : with torch.no_grad(), model.eval()

# %%
# 데이터 파서 : 모델의 응답에서 선지를 추출
def extract_choice(text: str) -> str:
    text = text.strip().lower()

    lines = [l.strip() for l in text.splitlines() if l.strip()]
    if not lines:
        return "a"
    last = lines[-1]
    if last in ["a", "b", "c", "d"]:
        return last

    tokens = last.split()
    for tok in tokens:
        if tok in ["a", "b", "c", "d"]:
            return tok
    return "a"

# 추론을 위해 모든 레이어 활성화
model.eval()
preds = []

# 추론 루프
for i in tqdm(range(len(test_df)), desc="Inference", unit="sample"):
    row = test_df.iloc[i]
    img = Image.open(row["path"]).convert("RGB")
    user_text = build_mc_prompt(row["question"], row["a"], row["b"], row["c"], row["d"])

    messages = [
        {"role":"system","content":[{"type":"text","text":SYSTEM_INSTRUCT}]},
        {"role":"user","content":[
            {"type":"image","image":img},
            {"type":"text","text":user_text}
        ]}
    ]

    text = processor.apply_chat_template(messages, tokenize=False, add_generation_prompt=True)
    inputs = processor(text=[text], images=[img], return_tensors="pt").to(device)

    with torch.no_grad():
        out_ids = model.generate(**inputs, max_new_tokens=2, do_sample=False,
                                 eos_token_id=processor.tokenizer.eos_token_id)
    output_text = processor.batch_decode(out_ids, skip_special_tokens=True)[0]
    # print("output_text:", output_text)
    # print("extract_choice:", extract_choice(output_text))
    preds.append(extract_choice(output_text))

# 제출 파일 생성
submission = pd.DataFrame({"id": test_df["id"], "answer": preds})
submission.to_csv("/content/submission.csv", index=False)
print("Saved /content/submission.csv")
# Out:
# Inference:   0%|          | 0/3887 [00:00<?, ?sample/s]
# Saved /content/submission.csv

# %%
# 제출 파일 생성
save_path1 = "/content/drive/My Drive/epoch2_submission.csv"
submission.to_csv(save_path1, index=False)
print(f"Saved: {save_path1}")
# Out:
# Saved: /content/drive/My Drive/epoch2_submission.csv
